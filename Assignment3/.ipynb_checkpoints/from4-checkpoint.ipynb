# %%
import os
import numpy as np
import trimesh
import pyrender
import h5py
from mesh_to_png import mesh_to_png
from landmarks import detect_landmark
from data_def import PCAModel, Mesh
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import torch
import torch.nn as nn
from torch.autograd import Variable
from collections import namedtuple

# %%
# Section 4
face_image = mpimg.imread('leo.jpg')
# face_image = (doge_image[:, :, :3] * 256).astype(np.uint8)
face_landmarks_gt = detect_landmark(face_image)
H, W = face_image.shape[0], face_image.shape[1]

fig = plt.figure(figsize = (15,10))
plt.imshow(face_image)
plt.scatter(face_landmarks_gt[:, 0], face_landmarks_gt[:, 1])
plt.axes().set_aspect('equal')
plt.show()
fig.savefig('results/face_landmarks_gt.png')

# %%
def load_bfm(N_id, N_exp):
    bfm = h5py.File("model2017-1_face12_nomouth.h5", 'r')
    mean_tex = np.asarray(bfm['color/model/mean'], dtype=np.float32).reshape((-1, 3))
    triangles = np.asarray(bfm['shape/representer/cells'], dtype=np.int32).T
    # PCA model for facial identity.
    mu_id = np.asarray(bfm['shape/model/mean'], dtype=np.float32).reshape((-1, 3))
    pcaBasis_id = np.asarray(bfm['shape/model/pcaBasis'], dtype=np.float32).reshape((-1, 3, 199))
    pcaVariance_id = np.asarray(bfm['shape/model/pcaVariance'], dtype=np.float32)
    # PCA model for expression.
    mu_exp = np.asarray(bfm['expression/model/mean'], dtype=np.float32).reshape((-1, 3))
    pcaBasis_exp = np.asarray(bfm['expression/model/pcaBasis'], dtype=np.float32).reshape((-1, 3, 100))
    pcaVariance_exp = np.asarray(bfm['expression/model/pcaVariance'], dtype=np.float32)

    # Pick the largest N_id and N_exp principal components and variances for facial identity and expressions respectively.
    E_id = pcaBasis_id[:, :, :N_id]
    E_exp = pcaBasis_exp[:, :, :N_exp]
    sigma_id = np.sqrt(pcaVariance_id[:N_id])
    sigma_exp = np.sqrt(pcaVariance_exp[:N_exp])

    # Convert all to PyTorch tensors.
    mu_id_torch = torch.Tensor(mu_id)
    mu_exp_torch = torch.Tensor(mu_exp)
    E_id_torch = torch.Tensor(E_id)
    E_exp_torch = torch.Tensor(E_exp)
    sigma_id_torch = torch.Tensor(sigma_id)
    sigma_exp_torch = torch.Tensor(sigma_exp)
    return mu_id_torch, mu_exp_torch, E_id_torch, E_exp_torch, sigma_id_torch, sigma_exp_torch

def load_landmark_inds():
    # Read facial landmark indices.
    landmarks=[]
    with open('Landmarks68_model2017-1_face12_nomouth.anl','r') as f:
        for line in f.readlines():
            landmarks.append(int(line.split('\n')[0]))
    landmarks = torch.tensor(landmarks)
    return landmarks

def Projection(W, H, f, n, fovy):
    # Define camera projection matrices.
    V = torch.Tensor([[W/2, 0, 0, W/2],
                      [0, -H/2, 0, H/2],
                      [0, 0, 0.5, 0.5],
                      [0, 0, 0, 1]
                     ])

    aspect_ratio = W / H
    t = np.tan(fovy / 2) * n
    b = -t
    r = t * aspect_ratio
    l = -t * aspect_ratio
    P = torch.Tensor([[(2*n)/(r-l),0,(r+l)/(r-l),0],
                  [0,(2*n)/(t-b),(t+b)/(t-b),0],
                  [0,0,-(f+n)/(f-n),-(2*f*n)/(f-n)],
                  [0,0,-1,0]])
    return V, P
def Rotation(omega):
    # Define Rotation matrix.
    Rx, Ry, Rz = torch.zeros(3, 3), torch.zeros(3, 3), torch.zeros(3, 3)
    Rx[0, 0] = 1.
    Rx[1, 1] = torch.cos(omega[0])
    Rx[1, 2] = -torch.sin(omega[0])
    Rx[2, 1] = torch.sin(omega[0])
    Rx[2, 2] = torch.cos(omega[0])

    Ry[0, 0] = torch.cos(omega[1])
    Ry[0, 2] = torch.sin(omega[1])
    Ry[1, 1] = 1.
    Ry[2, 0] = -torch.sin(omega[1])
    Ry[2, 2] = torch.cos(omega[1])
    
    Rz[0, 0] = torch.cos(omega[2])
    Rz[0, 1] = -torch.sin(omega[2])
    Rz[1, 0] = torch.sin(omega[2])
    Rz[1, 1] = torch.cos(omega[2])
    Rz[2, 2] = 1.
    
    R = Rx @ Ry @ Rz    
    return R

params = namedtuple('params', ['N_id', 'N_exp', 'epochs', 'lambda_alpha', 'lambda_delta', 'far', 'near', 'fovy', 'uni'])
outputs = namedtuple('outputs', ['losses_land', 'losses_reg', 'V', 'P', 'alpha', 'delta', 'omega', 't'])
fit_params = namedtuple('fit_params', ['V', 'P', 'alpha', 'delta', 'omega', 't'])

def train(params, face_landmarks_gt):
    # Extract parameters.
    N_id = params.N_id
    N_exp = params.N_exp
    epochs = params.epochs
    lambda_alpha = params.lambda_alpha
    lambda_delta = params.lambda_delta
    far = params.far
    near = params.near
    fovy = params.fovy
    uni = params.uni
    
    # Read Basel Face Model.
    mu_id_torch, mu_exp_torch, E_id_torch, E_exp_torch, sigma_id_torch, sigma_exp_torch = load_bfm(N_id, N_exp)
    landmarks = load_landmark_inds()

    # Define groundtruth facial landmarks.
    gt_landmark = torch.Tensor(face_landmarks_gt).t()

    # Initialize trainable variables.
    alpha = Variable(torch.FloatTensor(N_id).uniform_(-uni, uni), requires_grad=True)
    delta = Variable(torch.FloatTensor(N_exp).uniform_(-uni, uni), requires_grad=True)
#     alpha = Variable(torch.randn(N_id), requires_grad=True)
#     delta = Variable(torch.randn(N_exp), requires_grad=True)
    omega = Variable(torch.zeros(3), requires_grad=True)
    t = Variable(torch.Tensor([0, 0, -400]), requires_grad=True)

    # Initialize optimizer.
    opt = torch.optim.Adam([alpha, delta, omega, t], lr=0.1)

    # Define camera projection matrices.
    V, P = Projection(W, H, far, near, fovy)

    # Working quite good as well.
    # n = 300.
    # f = 2000.
    # fovy = 0.5
    # e = 1 / np.tan(fovy / 2)
    # a = H / W
    # P = torch.Tensor([[e, 0, 0, 0],
    #                   [0, e/a, 0, 0],
    #                   [0, 0, -(f + n)/(f-n), -2*f*n/(f - n)],
    #                   [0, 0, -1, 0]
    #                  ])

    losses_land = []
    losses_reg = []

    for epoch in np.arange(epochs):
        opt.zero_grad()    
        G = mu_id_torch + E_id_torch @ (alpha * sigma_id_torch) + mu_exp_torch + E_exp_torch @ (delta * sigma_exp_torch)    
        G_landmark_tmp = torch.transpose(torch.index_select(G, 0, landmarks), 0, 1)
        G_landmark = torch.cat((G_landmark_tmp, torch.ones(1, len(landmarks))), 0)

        # Define the Rotation matrix.
        R = Rotation(omega)

        # Define the Translation matrix.
        T = torch.cat((torch.cat((R, t.view(-1, 1)), dim=1), torch.tensor([0., 0., 0., 1.]).view(1, -1)), dim=0)   

        out = V @ P @ T @ G_landmark
        pred_landmark = torch.empty_like(gt_landmark)
        # Divide by the homogeneous dimension.
        pred_landmark[0, :] = out[0, :] / out[3, :]
        pred_landmark[1, :] = out[1, :] / out[3, :]

        L_landmark = (pred_landmark - gt_landmark).pow(2).sum(dim=0).sqrt().sum()
        L_regularizer = lambda_alpha * alpha.pow(2).sum() + lambda_delta * delta.pow(2).sum()
        L_fit = L_landmark + L_regularizer
        L_fit.backward(retain_graph=True)
        opt.step()    
        losses_land.append(L_landmark.item())
        losses_reg.append(L_regularizer)
        print('Epoch: {}, L_landmark: {:.3f}, L_regularizer: {:.3f}'.format(epoch, L_landmark, L_regularizer))    
    return outputs(losses_land, losses_reg, V.detach(), P.detach(), alpha.detach(), delta.detach(), omega.detach(), t.detach())


def fit(fit_params):
    V = fit_params.V
    P = fit_params.P
    alpha = fit_params.alpha
    delta = fit_params.delta
    omega = fit_params.omega
    t = fit_params.t
    N_id = alpha.shape[0]
    N_exp = delta.shape[0]
    mu_id_torch, mu_exp_torch, E_id_torch, E_exp_torch, sigma_id_torch, sigma_exp_torch = load_bfm(N_id, N_exp)
    G = mu_id_torch + E_id_torch @ (alpha * sigma_id_torch) + mu_exp_torch + E_exp_torch @ (delta * sigma_exp_torch)
    R = Rotation(omega)
    T = torch.cat((torch.cat((R, t.view(-1, 1)), dim=1), torch.tensor([0., 0., 0., 1.]).view(1, -1)), dim=0)   
    G_homo = torch.cat((G.t(), torch.ones(1, G.shape[0])), dim=0)
    G_transformed = V @ P @ T @ G_homo
    return G_transformed

# %%
# Define Hyperparameters.
N_id = 30
N_exp = 20
epochs = 500
lambda_alpha = 1
lambda_delta = 1
far = 2000.
near = 300.
fovy = 0.5
uni = 1
train_params = params(N_id, N_exp, epochs, lambda_alpha, lambda_delta, far, near, fovy, uni)

# Train.
train_outputs = train(train_params, face_landmarks_gt)
losses_land = train_outputs.losses_land
losses_reg = train_outputs.losses_reg 
V = train_outputs.V 
P = train_outputs.P
alpha = train_outputs.alpha
delta = train_outputs.delta
omega = train_outputs.omega
t = train_outputs.t
# Out:
# Epoch: 0, L_landmark: 18417.381, L_regularizer: 17.470
# Epoch: 1, L_landmark: 18786.535, L_regularizer: 18.009
# Epoch: 2, L_landmark: 17838.781, L_regularizer: 18.501
# Epoch: 3, L_landmark: 17282.305, L_regularizer: 19.368
# Epoch: 4, L_landmark: 16742.332, L_regularizer: 20.675
# Epoch: 5, L_landmark: 16227.129, L_regularizer: 22.652
# Epoch: 6, L_landmark: 15803.126, L_regularizer: 25.375
# Epoch: 7, L_landmark: 15411.042, L_regularizer: 28.925
# Epoch: 8, L_landmark: 14979.539, L_regularizer: 33.268
# Epoch: 9, L_landmark: 14510.712, L_regularizer: 38.294
# Epoch: 10, L_landmark: 14058.528, L_regularizer: 43.851
# Epoch: 11, L_landmark: 13612.260, L_regularizer: 49.887
# Epoch: 60, L_landmark: 2773.936, L_regularizer: 466.738
# Epoch: 61, L_landmark: 2533.409, L_regularizer: 469.510
# Epoch: 62, L_landmark: 2593.908, L_regularizer: 471.682
# Epoch: 63, L_landmark: 2380.250, L_regularizer: 473.373
# Epoch: 64, L_landmark: 2448.925, L_regularizer: 474.620
# Epoch: 65, L_landmark: 2220.515, L_regularizer: 475.845
# Epoch: 66, L_landmark: 2261.411, L_regularizer: 476.936
# Epoch: 67, L_landmark: 2079.876, L_regularizer: 477.802
# Epoch: 68, L_landmark: 2134.541, L_regularizer: 478.640
# Epoch: 69, L_landmark: 2044.586, L_regularizer: 479.702
# Epoch: 70, L_landmark: 1958.590, L_regularizer: 480.588
# Epoch: 71, L_landmark: 1907.122, L_regularizer: 481.566
# Epoch: 72, L_landmark: 1840.134, L_regularizer: 482.608
# Epoch: 73, L_landmark: 1849.408, L_regularizer: 483.492
# Epoch: 74, L_landmark: 1708.782, L_regularizer: 484.439
# Epoch: 75, L_landmark: 1755.089, L_regularizer: 485.279
# Epoch: 76, L_landmark: 1787.324, L_regularizer: 485.922
# Epoch: 77, L_landmark: 1650.098, L_regularizer: 486.512
# Epoch: 78, L_landmark: 1663.932, L_regularizer: 486.854
# Epoch: 79, L_landmark: 1698.775, L_regularizer: 486.935
# Epoch: 80, L_landmark: 1572.346, L_regularizer: 487.080
# Epoch: 81, L_landmark: 1531.134, L_regularizer: 486.848
# Epoch: 82, L_landmark: 1596.255, L_regularizer: 486.290
# Epoch: 83, L_landmark: 1418.489, L_regularizer: 485.762
# Epoch: 84, L_landmark: 1436.677, L_regularizer: 484.909
# Epoch: 85, L_landmark: 1412.258, L_regularizer: 483.693
# Epoch: 86, L_landmark: 1325.683, L_regularizer: 482.397
# Epoch: 87, L_landmark: 1317.301, L_regularizer: 480.781
# Epoch: 88, L_landmark: 1316.554, L_regularizer: 478.856
# Epoch: 89, L_landmark: 1283.160, L_regularizer: 476.868
# Epoch: 90, L_landmark: 1243.674, L_regularizer: 474.595
# Epoch: 91, L_landmark: 1251.990, L_regularizer: 472.301
# Epoch: 92, L_landmark: 1233.646, L_regularizer: 470.003
# Epoch: 93, L_landmark: 1178.300, L_regularizer: 467.641
# Epoch: 94, L_landmark: 1176.397, L_regularizer: 465.251
# Epoch: 95, L_landmark: 1220.603, L_regularizer: 462.969
# Epoch: 96, L_landmark: 1145.156, L_regularizer: 460.741
# Epoch: 97, L_landmark: 1103.868, L_regularizer: 458.655
# Epoch: 98, L_landmark: 1095.161, L_regularizer: 456.641
# Epoch: 99, L_landmark: 1095.763, L_regularizer: 454.686
# Epoch: 100, L_landmark: 1134.102, L_regularizer: 452.954
# Epoch: 101, L_landmark: 1074.703, L_regularizer: 451.121
# Epoch: 102, L_landmark: 1045.696, L_regularizer: 449.496
# Epoch: 103, L_landmark: 1048.920, L_regularizer: 447.867
# Epoch: 104, L_landmark: 1022.620, L_regularizer: 446.324
# Epoch: 105, L_landmark: 1054.104, L_regularizer: 445.003
# Epoch: 106, L_landmark: 1026.031, L_regularizer: 443.555
# Epoch: 107, L_landmark: 966.740, L_regularizer: 442.302
# Epoch: 108, L_landmark: 963.992, L_regularizer: 441.072
# Epoch: 109, L_landmark: 1003.677, L_regularizer: 439.880
# Epoch: 110, L_landmark: 962.802, L_regularizer: 438.764
# Epoch: 111, L_landmark: 937.324, L_regularizer: 437.567
# Epoch: 112, L_landmark: 993.240, L_regularizer: 436.530
# Epoch: 113, L_landmark: 976.829, L_regularizer: 435.350
# Epoch: 114, L_landmark: 933.059, L_regularizer: 434.249
# Epoch: 115, L_landmark: 917.776, L_regularizer: 433.006
# Epoch: 116, L_landmark: 962.981, L_regularizer: 431.706
# Epoch: 117, L_landmark: 943.347, L_regularizer: 430.224
# Epoch: 118, L_landmark: 888.786, L_regularizer: 428.542
# Epoch: 119, L_landmark: 878.850, L_regularizer: 426.879
# Epoch: 120, L_landmark: 932.928, L_regularizer: 425.081
# Epoch: 121, L_landmark: 927.262, L_regularizer: 423.374
# Epoch: 122, L_landmark: 867.540, L_regularizer: 421.466
# Epoch: 123, L_landmark: 868.687, L_regularizer: 419.698
# Epoch: 124, L_landmark: 902.583, L_regularizer: 417.817
# Epoch: 125, L_landmark: 924.248, L_regularizer: 416.171
# Epoch: 126, L_landmark: 859.297, L_regularizer: 414.369
# Epoch: 127, L_landmark: 851.856, L_regularizer: 412.805
# Epoch: 128, L_landmark: 865.215, L_regularizer: 411.229
# Epoch: 129, L_landmark: 876.294, L_regularizer: 409.749
# Epoch: 130, L_landmark: 843.788, L_regularizer: 408.306
# Epoch: 131, L_landmark: 821.303, L_regularizer: 406.870
# Epoch: 132, L_landmark: 857.398, L_regularizer: 405.603
# Epoch: 133, L_landmark: 913.375, L_regularizer: 404.143
# Epoch: 134, L_landmark: 804.118, L_regularizer: 402.904
# Epoch: 135, L_landmark: 792.358, L_regularizer: 401.539
# Epoch: 136, L_landmark: 803.966, L_regularizer: 400.254
# Epoch: 137, L_landmark: 835.404, L_regularizer: 398.985
# Epoch: 138, L_landmark: 870.186, L_regularizer: 397.626
# Epoch: 139, L_landmark: 835.418, L_regularizer: 396.375
# Epoch: 140, L_landmark: 830.213, L_regularizer: 394.963
# Epoch: 141, L_landmark: 818.888, L_regularizer: 393.697
# Epoch: 142, L_landmark: 844.025, L_regularizer: 392.295
# Epoch: 143, L_landmark: 876.744, L_regularizer: 391.007
# Epoch: 144, L_landmark: 794.127, L_regularizer: 389.463
# Epoch: 145, L_landmark: 800.328, L_regularizer: 387.828
# Epoch: 146, L_landmark: 855.806, L_regularizer: 386.268
# Epoch: 147, L_landmark: 832.862, L_regularizer: 384.595
# Epoch: 148, L_landmark: 784.554, L_regularizer: 383.187
# Epoch: 149, L_landmark: 789.867, L_regularizer: 381.811
# Epoch: 150, L_landmark: 828.394, L_regularizer: 380.502
# Epoch: 151, L_landmark: 850.761, L_regularizer: 379.107
# Epoch: 152, L_landmark: 849.180, L_regularizer: 377.683
# Epoch: 153, L_landmark: 791.072, L_regularizer: 376.246
# Epoch: 154, L_landmark: 726.368, L_regularizer: 374.799
# Epoch: 155, L_landmark: 778.147, L_regularizer: 373.505
# Epoch: 204, L_landmark: 710.441, L_regularizer: 327.610
# Epoch: 205, L_landmark: 653.124, L_regularizer: 326.767
# Epoch: 206, L_landmark: 762.305, L_regularizer: 325.941
# Epoch: 207, L_landmark: 741.567, L_regularizer: 325.252
# Epoch: 208, L_landmark: 754.984, L_regularizer: 324.587
# Epoch: 209, L_landmark: 660.386, L_regularizer: 323.796
# Epoch: 210, L_landmark: 749.924, L_regularizer: 323.130
# Epoch: 211, L_landmark: 770.066, L_regularizer: 322.504
# Epoch: 212, L_landmark: 729.921, L_regularizer: 322.027
# Epoch: 213, L_landmark: 652.075, L_regularizer: 321.488
# Epoch: 214, L_landmark: 787.353, L_regularizer: 321.020
# Epoch: 215, L_landmark: 685.701, L_regularizer: 320.540
# Epoch: 216, L_landmark: 691.140, L_regularizer: 320.034
# Epoch: 217, L_landmark: 634.429, L_regularizer: 319.348
# Epoch: 218, L_landmark: 701.363, L_regularizer: 318.661
# Epoch: 219, L_landmark: 728.855, L_regularizer: 317.993
# Epoch: 220, L_landmark: 730.110, L_regularizer: 317.417
# Epoch: 221, L_landmark: 644.535, L_regularizer: 316.708
# Epoch: 222, L_landmark: 645.259, L_regularizer: 316.082
# Epoch: 223, L_landmark: 704.905, L_regularizer: 315.593
# Epoch: 224, L_landmark: 707.143, L_regularizer: 315.133
# Epoch: 225, L_landmark: 738.159, L_regularizer: 314.636
# Epoch: 226, L_landmark: 645.723, L_regularizer: 314.245
# Epoch: 227, L_landmark: 729.843, L_regularizer: 313.900
# Epoch: 228, L_landmark: 704.894, L_regularizer: 313.494
# Epoch: 229, L_landmark: 643.129, L_regularizer: 312.873
# Epoch: 230, L_landmark: 643.885, L_regularizer: 312.241
# Epoch: 231, L_landmark: 774.316, L_regularizer: 311.649
# Epoch: 232, L_landmark: 702.856, L_regularizer: 310.882
# Epoch: 233, L_landmark: 614.856, L_regularizer: 310.179
# Epoch: 234, L_landmark: 798.915, L_regularizer: 309.688
# Epoch: 235, L_landmark: 726.546, L_regularizer: 309.146
# Epoch: 236, L_landmark: 625.204, L_regularizer: 308.739
# Epoch: 237, L_landmark: 727.187, L_regularizer: 308.408
# Epoch: 238, L_landmark: 778.757, L_regularizer: 307.865
# Epoch: 239, L_landmark: 609.074, L_regularizer: 307.476
# Epoch: 240, L_landmark: 620.534, L_regularizer: 307.010
# Epoch: 241, L_landmark: 739.090, L_regularizer: 306.393
# Epoch: 242, L_landmark: 708.519, L_regularizer: 305.913
# Epoch: 243, L_landmark: 621.526, L_regularizer: 305.340
# Epoch: 244, L_landmark: 612.684, L_regularizer: 304.862
# Epoch: 245, L_landmark: 650.796, L_regularizer: 304.283
# Epoch: 246, L_landmark: 680.902, L_regularizer: 303.811
# Epoch: 247, L_landmark: 705.879, L_regularizer: 303.231
# Epoch: 248, L_landmark: 648.641, L_regularizer: 302.703
# Epoch: 249, L_landmark: 633.626, L_regularizer: 302.058
# Epoch: 250, L_landmark: 658.758, L_regularizer: 301.486
# Epoch: 251, L_landmark: 710.591, L_regularizer: 301.065
# Epoch: 252, L_landmark: 699.130, L_regularizer: 300.752
# Epoch: 253, L_landmark: 616.482, L_regularizer: 300.374
# Epoch: 254, L_landmark: 612.431, L_regularizer: 300.062
# Epoch: 255, L_landmark: 666.742, L_regularizer: 299.839
# Epoch: 256, L_landmark: 728.597, L_regularizer: 299.646
# Epoch: 257, L_landmark: 632.869, L_regularizer: 299.327
# Epoch: 258, L_landmark: 636.198, L_regularizer: 298.996
# Epoch: 259, L_landmark: 691.887, L_regularizer: 298.627
# Epoch: 260, L_landmark: 650.388, L_regularizer: 298.258
# Epoch: 261, L_landmark: 636.324, L_regularizer: 297.768
# Epoch: 262, L_landmark: 612.869, L_regularizer: 297.307
# Epoch: 263, L_landmark: 675.070, L_regularizer: 296.965
# Epoch: 264, L_landmark: 636.935, L_regularizer: 296.501
# Epoch: 265, L_landmark: 660.296, L_regularizer: 296.037
# Epoch: 266, L_landmark: 670.482, L_regularizer: 295.621
# Epoch: 267, L_landmark: 673.641, L_regularizer: 295.326
# Epoch: 268, L_landmark: 621.833, L_regularizer: 294.845
# Epoch: 269, L_landmark: 615.551, L_regularizer: 294.385
# Epoch: 270, L_landmark: 613.479, L_regularizer: 293.961
# Epoch: 271, L_landmark: 666.398, L_regularizer: 293.650
# Epoch: 272, L_landmark: 692.058, L_regularizer: 293.243
# Epoch: 273, L_landmark: 606.408, L_regularizer: 292.983
# Epoch: 274, L_landmark: 647.974, L_regularizer: 292.840
# Epoch: 275, L_landmark: 750.969, L_regularizer: 292.847
# Epoch: 276, L_landmark: 609.493, L_regularizer: 292.722
# Epoch: 277, L_landmark: 576.761, L_regularizer: 292.508
# Epoch: 278, L_landmark: 590.587, L_regularizer: 292.207
# Epoch: 279, L_landmark: 632.923, L_regularizer: 291.818
# Epoch: 280, L_landmark: 734.386, L_regularizer: 291.373
# Epoch: 281, L_landmark: 668.488, L_regularizer: 291.018
# Epoch: 282, L_landmark: 589.932, L_regularizer: 290.661
# Epoch: 283, L_landmark: 630.635, L_regularizer: 290.402
# Epoch: 284, L_landmark: 757.541, L_regularizer: 290.098
# Epoch: 285, L_landmark: 603.445, L_regularizer: 289.826
# Epoch: 286, L_landmark: 621.556, L_regularizer: 289.581
# Epoch: 287, L_landmark: 752.128, L_regularizer: 289.233
# Epoch: 288, L_landmark: 601.801, L_regularizer: 288.922
# Epoch: 289, L_landmark: 583.518, L_regularizer: 288.528
# Epoch: 290, L_landmark: 626.689, L_regularizer: 288.092
# Epoch: 291, L_landmark: 686.289, L_regularizer: 287.653
# Epoch: 292, L_landmark: 662.542, L_regularizer: 287.212
# Epoch: 293, L_landmark: 587.565, L_regularizer: 286.795
# Epoch: 294, L_landmark: 623.362, L_regularizer: 286.439
# Epoch: 295, L_landmark: 716.900, L_regularizer: 286.118
# Epoch: 296, L_landmark: 610.094, L_regularizer: 285.878
# Epoch: 297, L_landmark: 586.962, L_regularizer: 285.545
# Epoch: 298, L_landmark: 629.411, L_regularizer: 285.151
# Epoch: 299, L_landmark: 664.144, L_regularizer: 284.808
# Epoch: 300, L_landmark: 651.581, L_regularizer: 284.515
# Epoch: 301, L_landmark: 590.232, L_regularizer: 284.219
# Epoch: 399, L_landmark: 546.582, L_regularizer: 267.204
# Epoch: 400, L_landmark: 571.773, L_regularizer: 267.047
# Epoch: 401, L_landmark: 669.021, L_regularizer: 266.873
# Epoch: 402, L_landmark: 632.139, L_regularizer: 266.744
# Epoch: 403, L_landmark: 550.429, L_regularizer: 266.569
# Epoch: 404, L_landmark: 543.276, L_regularizer: 266.372
# Epoch: 405, L_landmark: 590.000, L_regularizer: 266.243
# Epoch: 406, L_landmark: 674.775, L_regularizer: 266.137
# Epoch: 407, L_landmark: 561.970, L_regularizer: 266.075
# Epoch: 408, L_landmark: 581.430, L_regularizer: 266.145
# Epoch: 409, L_landmark: 680.824, L_regularizer: 266.095
# Epoch: 410, L_landmark: 560.140, L_regularizer: 265.936
# Epoch: 411, L_landmark: 544.434, L_regularizer: 265.706
# Epoch: 412, L_landmark: 567.966, L_regularizer: 265.510
# Epoch: 413, L_landmark: 677.047, L_regularizer: 265.341
# Epoch: 414, L_landmark: 623.535, L_regularizer: 265.243
# Epoch: 415, L_landmark: 537.401, L_regularizer: 265.141
# Epoch: 416, L_landmark: 570.409, L_regularizer: 265.035
# Epoch: 417, L_landmark: 659.970, L_regularizer: 264.862
# Epoch: 418, L_landmark: 555.996, L_regularizer: 264.770
# Epoch: 419, L_landmark: 533.568, L_regularizer: 264.733
# Epoch: 420, L_landmark: 576.353, L_regularizer: 264.840
# Epoch: 421, L_landmark: 648.650, L_regularizer: 265.042
# Epoch: 422, L_landmark: 622.815, L_regularizer: 265.239
# Epoch: 423, L_landmark: 544.058, L_regularizer: 265.295
# Epoch: 424, L_landmark: 615.699, L_regularizer: 265.289
# Epoch: 425, L_landmark: 660.196, L_regularizer: 265.165
# Epoch: 426, L_landmark: 536.542, L_regularizer: 265.075
# Epoch: 427, L_landmark: 630.389, L_regularizer: 265.170
# Epoch: 428, L_landmark: 673.050, L_regularizer: 265.160
# Epoch: 429, L_landmark: 531.148, L_regularizer: 265.074
# Epoch: 430, L_landmark: 598.487, L_regularizer: 265.109
# Epoch: 431, L_landmark: 682.278, L_regularizer: 265.006
# Epoch: 432, L_landmark: 529.134, L_regularizer: 264.911
# Epoch: 433, L_landmark: 580.234, L_regularizer: 264.900
# Epoch: 434, L_landmark: 726.192, L_regularizer: 264.746
# Epoch: 435, L_landmark: 548.645, L_regularizer: 264.567
# Epoch: 436, L_landmark: 661.310, L_regularizer: 264.451
# Epoch: 437, L_landmark: 677.660, L_regularizer: 264.191
# Epoch: 438, L_landmark: 559.282, L_regularizer: 263.794
# Epoch: 439, L_landmark: 784.783, L_regularizer: 263.476
# Epoch: 440, L_landmark: 552.392, L_regularizer: 263.212
# Epoch: 441, L_landmark: 642.599, L_regularizer: 263.123
# Epoch: 442, L_landmark: 717.962, L_regularizer: 263.002
# Epoch: 443, L_landmark: 549.475, L_regularizer: 262.947
# Epoch: 444, L_landmark: 799.022, L_regularizer: 263.084
# Epoch: 445, L_landmark: 566.632, L_regularizer: 263.095
# Epoch: 446, L_landmark: 716.043, L_regularizer: 263.203
# Epoch: 447, L_landmark: 624.333, L_regularizer: 263.404
# Epoch: 448, L_landmark: 565.788, L_regularizer: 263.722
# Epoch: 449, L_landmark: 727.963, L_regularizer: 263.992
# Epoch: 450, L_landmark: 548.085, L_regularizer: 264.043
# Epoch: 451, L_landmark: 572.000, L_regularizer: 263.984
# Epoch: 452, L_landmark: 656.788, L_regularizer: 263.842
# Epoch: 453, L_landmark: 551.603, L_regularizer: 263.503
# Epoch: 454, L_landmark: 575.064, L_regularizer: 263.148
# Epoch: 455, L_landmark: 644.038, L_regularizer: 262.865
# Epoch: 456, L_landmark: 574.714, L_regularizer: 262.690
# Epoch: 457, L_landmark: 567.685, L_regularizer: 262.728
# Epoch: 458, L_landmark: 634.895, L_regularizer: 262.939
# Epoch: 459, L_landmark: 545.247, L_regularizer: 263.148
# Epoch: 460, L_landmark: 570.771, L_regularizer: 263.355
# Epoch: 461, L_landmark: 660.760, L_regularizer: 263.346
# Epoch: 462, L_landmark: 570.548, L_regularizer: 263.320
# Epoch: 463, L_landmark: 566.143, L_regularizer: 263.265
# Epoch: 464, L_landmark: 631.697, L_regularizer: 263.198
# Epoch: 465, L_landmark: 559.764, L_regularizer: 262.968
# Epoch: 466, L_landmark: 549.330, L_regularizer: 262.795
# Epoch: 467, L_landmark: 606.104, L_regularizer: 262.759
# Epoch: 468, L_landmark: 615.655, L_regularizer: 262.726
# Epoch: 469, L_landmark: 559.252, L_regularizer: 262.474
# Epoch: 470, L_landmark: 588.102, L_regularizer: 262.137
# Epoch: 471, L_landmark: 602.478, L_regularizer: 261.843
# Epoch: 472, L_landmark: 545.242, L_regularizer: 261.582
# Epoch: 473, L_landmark: 547.438, L_regularizer: 261.378
# Epoch: 474, L_landmark: 611.762, L_regularizer: 261.246
# Epoch: 475, L_landmark: 584.910, L_regularizer: 261.198
# Epoch: 476, L_landmark: 553.639, L_regularizer: 261.258
# Epoch: 477, L_landmark: 581.442, L_regularizer: 261.386
# Epoch: 478, L_landmark: 589.760, L_regularizer: 261.454
# Epoch: 479, L_landmark: 580.704, L_regularizer: 261.467
# Epoch: 480, L_landmark: 553.108, L_regularizer: 261.392
# Epoch: 481, L_landmark: 567.180, L_regularizer: 261.278
# Epoch: 482, L_landmark: 584.908, L_regularizer: 261.145
# Epoch: 483, L_landmark: 590.023, L_regularizer: 261.096
# Epoch: 484, L_landmark: 554.927, L_regularizer: 261.079
# Epoch: 485, L_landmark: 561.859, L_regularizer: 261.133
# Epoch: 486, L_landmark: 577.328, L_regularizer: 261.084
# Epoch: 487, L_landmark: 597.826, L_regularizer: 260.824
# Epoch: 488, L_landmark: 575.628, L_regularizer: 260.591
# Epoch: 489, L_landmark: 562.699, L_regularizer: 260.311
# Epoch: 490, L_landmark: 544.925, L_regularizer: 260.125
# Epoch: 491, L_landmark: 554.986, L_regularizer: 260.110
# Epoch: 492, L_landmark: 583.913, L_regularizer: 260.164
# Epoch: 493, L_landmark: 601.068, L_regularizer: 260.256
# Epoch: 494, L_landmark: 560.344, L_regularizer: 260.335
# Epoch: 495, L_landmark: 548.688, L_regularizer: 260.376
# Epoch: 496, L_landmark: 558.363, L_regularizer: 260.376
# Epoch: 497, L_landmark: 569.487, L_regularizer: 260.248
# Epoch: 498, L_landmark: 547.511, L_regularizer: 260.155
# Epoch: 499, L_landmark: 534.999, L_regularizer: 260.014

# %%
fig = plt.figure(figsize= (15, 10))
plt.subplot(1, 2, 1)
plt.plot(np.arange(epochs), losses_land)
plt.xlabel('Epochs')
plt.ylabel('$\mathcal{L}_{l a n}$')
plt.subplot(1, 2, 2)
plt.plot(np.arange(epochs), losses_reg)
plt.xlabel('Epochs')
plt.ylabel('$\mathcal{L}_{r e g}$')
plt.show()
fig.savefig('results/losses_uniform_{}.png'.format(str(uni).replace('.', '_')))

# %%
trained_params = fit_params(V, P, alpha, delta, omega, t)
transformed = fit(trained_params)
landmark_inds = load_landmark_inds()
pred_landmarks = torch.index_select(transformed, 1, landmark_inds)

# %%
fig = plt.figure(figsize = (15,10))
plt.imshow(face_image)
plt.scatter(face_landmarks_gt[:, 0], face_landmarks_gt[:, 1])
plt.scatter(pred_landmarks.numpy()[0, :] / pred_landmarks.numpy()[3, :], pred_landmarks.numpy()[1, :] / pred_landmarks.numpy()[3, :])
plt.axes().set_aspect('equal')
plt.show()
fig.savefig('results/landmarks_matches_uniform_{}.png'.format(str(uni).replace('.', '_')))

# %%
fig = plt.figure(figsize=(15, 10))
plt.imshow(face_image)
ax=fig.add_subplot(111)

ax.scatter(transformed.numpy()[0, :] / transformed.numpy()[3, :], transformed.numpy()[1, :] / transformed.numpy()[3, :], transformed.detach().numpy()[2, :] / transformed.numpy()[3, :], marker='.')
plt.show()
fig.savefig('results/point_cloud_fit_uniform_{}.png'.format(str(uni).replace('.', '_')))

# %%
# Section 5
transformed = np.array([
    transformed.numpy()[0, :] / transformed.numpy()[3, :], 
    transformed.numpy()[1, :] / transformed.numpy()[3, :],
    transformed.numpy()[2, :] / transformed.numpy()[3, :]
])

# %%
interpolated = np.empty_like(transformed, dtype=np.uint8)
for p_i in np.arange(transformed.shape[1]):
    y = transformed[0, p_i]
    x = transformed[1, p_i]
    y1 = int(np.ceil(y)) % H
    y2 = int(np.floor(y)) % H 
    x1 = int(np.floor(x)) % W
    x2 = int(np.ceil(x)) % W   
#     print('y: {}, y1: {}, y2: {}'.format(y, y1, y2))
#     print('x: {}, x1: {}, x2: {}'.format(x, x1, x2))
    Q11 = face_image[y1, x1, :]
    Q12 = face_image[y2, x1, :]
    Q21 = face_image[y1, x1, :]
    Q22 = face_image[y2, x2, :]
    denom = ((x2 - x1) * (y2 - y1))
    if np.isclose(denom, 0.):
        interpolated[:, p_i] = np.array([128, 128, 128])
        continue
    for i_c in np.arange(3):                
        tmp = 1./denom * np.array([x2 - x, x - x1]) @ np.array([[Q11[i_c], Q12[i_c]], [Q21[i_c], Q22[i_c]]]) @ np.array([y2 - y, y - y1])        
        interpolated[i_c, p_i] = tmp

bfm = h5py.File("model2017-1_face12_nomouth.h5", 'r')

triangles = np.asarray(bfm['shape/representer/cells'], dtype=np.int32).T
mesh = Mesh(transformed.T, interpolated.T / 255., triangles)
mesh_to_png('check.png', mesh)

# %%
# Section 6
# Out:
# 0
